# %%
df = pd.read_csv('/content/merged_df.csv')

'''

This codde will give us some information about the variables
Head will provide us with some schematic on how the table will look like
Info gives us the column name, how many non-null entries we have, and the data type of each feature
Descriptive Statistics: These provide us with an 8-number summary of the data including count, mean, min, max, standard deviation, and the quartiles
The last piece is a correlation matrix which tells us the correlation between two variables in matrix format
'''
print("First 5 rows of the data:")
print(df.head())


print("DataFrame Info:")
df.info()

print("\nDescriptive Statistics:")
print(df.describe())

print("Correlation Matrix:")
df['date_numeric'] = pd.to_datetime(df['date']).astype(int)
features = ["UNIXTime", "Radiation", "Temperature", "Pressure", "Humidity", "WindDirection(Degrees)", "Speed", "allsky_sfc_sw_dwn", "ws10m"]
print(df[features].corr())
